# %% [markdown]
# Generate intial word embedding for headlines and description

# %% [markdown]
# The embedding is limited to a fixed vocabulary size (`vocab_size`) but
# a vocabulary of all the words that appeared in the data is built.

# %%
import json
import pickle

# load the jsonl file
heads = []
descs = []
keywords = None

with open("data/signalmedia-1m.jsonl", "r") as ins:
    count = 1
    for line in ins:
        dataln = json.loads(line)
        '''
        for key in dataln:
            print(key)
        '''
        heads.append(dataln['title'])
        descs.append(dataln['content'])
        count +=1
        if count==1000:
            break

data_tuple = (heads, descs, keywords)
            
pickle.dump( data_tuple, open( "data/tokens.pkl", "wb" ) )

# %%
FN = 'vocabulary-embedding'

# %%
seed=42

# %%
vocab_size = 40000

# %%
embedding_dim = 100

# %%
lower = False # dont lower case the text

# %% [markdown]
# # read tokenized headlines and descriptions

# %%
FN0 = 'tokens' # this is the name of the data file which I assume you already have
with open('data/%s.pkl'%FN0, 'rb') as fp:
    heads, desc, keywords = pickle.load(fp) # keywords are not used in this project

# %%
if lower:
    heads = [h.lower() for h in heads]

# %%
if lower:
    desc = [h.lower() for h in desc]

# %%
i=0
heads[i]
# Out:
# 'Worcester breakfast club for veterans gives hunger its marching orders'

# %%
desc[i]
# Out:
# 'VETERANS saluted Worcester\'s first ever breakfast club for ex-soldiers which won over hearts, minds and bellies. \n \nThe Worcester Breakfast Club for HM Forces Veterans met at the Postal Order in Foregate Street at 10am on Saturday. \n \nThe club is designed to allow veterans a place to meet, socialise, eat and drink, giving hunger and loneliness their marching orders. \n \nFather-of-two Dave Carney, aged 43, of Merrimans Hill, Worcester, set up the club after being inspired by other similar clubs across the country. \n \nHe said: "As you can see from the picture, we had a good response. Five out of the 10 that attended said they saw the article in the newspaper and turned up. \n \n"We even had an old chap travel from Droitwich and he was late on parade by three hours. \n \n"It\'s generated a lot of interest and I estimate (from other veterans who saw the article) that next month\'s meeting will attract about 20 people. Onwards and upwards." \n \nHe said the management at the pub had been extremely hospitable to them. \n \nMr Carney said: "They bent over backwards for us. They really looked after us well. That is the best choice of venue I could have made. They even put \'reserved for the armed forces\'. \n   Promoted stories   \nThe reserve veteran with the Royal Engineers wanted to go to a breakfast club but found the nearest ones were in Bromsgrove and Gloucester so he decided to set up his own, closer to home. \n \nHe was influenced by Derek Hardman who set up a breakfast club for veterans in Hull and Andy Wilson who set one up in Newcastle. He said the idea has snowballed and there were now 70 similar clubs across the country and even some in Germany. \n \nMr Carney said with many Royal British Legion clubs closing he wanted veterans and serving personnel to feel they had somewhere they could go for good grub, beer and banter to recapture the comradery of being in the forces. \n \nThe Postal Order was chosen because of its central location and its proximity to the railway station and hotels and reasonably priced food and drink. \n \nThe management of the pub have even given the veterans a designated area within the pub. \n   \n Share article  \n   \nThe next meeting is at the Postal Order on Saturday, October 3 at 10am. \n \nThe breakfast club meets on the first Saturday of each month for those who want to attend in future.'

# %%
keywords[i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-6654b721a4bb> in <module>()
# ----> 1 keywords[i]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
len(heads),len(set(heads))
# Out:
# (999, 998)

# %%
len(desc),len(set(desc))
# Out:
# (999, 999)

# %% [markdown]
# # build vocabulary

# %%
from collections import Counter
from itertools import chain
def get_vocab(lst):
    vocabcount = Counter(w for txt in lst for w in txt.split())
    vocab = list(map(lambda x: x[0], sorted(vocabcount.items(), key=lambda x: -x[1])))
    return vocab, vocabcount

# %%
vocab, vocabcount = get_vocab(heads+desc)
print(vocab)
# Out:
# ['the', 'to', 'and', 'of', 'a', 'in', 'for', 'is', 'on', 'that', 'with', 'The', 'at', 'was', 'as', 'be', 'are', 'from', 'by', 'have', 'it', 'will', 'I', 'has', 'this', 'an', 'you', 'or', 'not', 'their', 'he', 'his', 'more', 'but', 'said', 'we', 'who', 'they', 'can', 'its', 'been', 'which', 'about', 'your', 'our', 'all', '-', 'were', 'also', 'out', 'one', 'had', 'up', 'new', 'would', 'her', 'than', '2015', 'first', 'when', 'into', 'over', 'after', 'my', 'other', 'so', 'what', '–', 'people', 'In', 'said.', 'two', 'like', 'she', 'just', '—', 'A', 'It', 'time', 'if', 'This', 'last', 'do', 'some', 'any', 'get', ',', 'there', 'no', 'only', 'make', 'could', 'how', 'most', 'them', 'He', 'September', 'But', 'back', 'New', 'these', 'should', 'Â', 'through', '.', 'per', 'because', 'We', 'now', 'where', 'before', 'against', 'being', 'those', 'may', '&', 'made', 'many', 'million', 'help', 'take', 'very', 'see', 'year', 'while', 'years', '--', 'us', 'even', 'him', 'three', 'good', 'going', 'much', 'second', 'For', 'during', 'since', 'around', 'use', 'company', 'To', 'way', 'work', 'off', 'need', 'me', 'down', 'team', 'including', 'well', 'want', 'market', 'And', 'then', 'set', 'game', 'go', 'still', 'You', 'next', 'home', 'If', 'such', 'both', 'between', 'every', 'part', 'best', 'business', 'come', 'day', 'really', 'told', 'think', '1', 'State', 'information', 'right', '2', 'know', 'They', 'did', '10', 'data', 'says', 'own', 'making', 'each', 'end', 'As', 'U.S.', 'All', 'US', 'it’s', 'number', 'support', 'find', 'look', 'report', 'found', 'top', 'season', 'used', 'another', 'here', 'place', 'under', 'got', 'few', 'same', 'across', 'local', 'world', 'With', '…', 'Mr', 'She', 'better', 'great', 'week', 'cent', 'World', 'On', 'visit', 'government', 'something', 'percent', 'until', 'lot', 'little', '"I', 'always', 'important', 'state', "it's", 'police', 'five', 'different', '0', 'play', 'tax', 'start', 'full', 'United', 'high', 'media', 'don’t', 'health', 'keep', 'working', 'say', 'live', 'year,', 'There', 'show', 'big', 'called', 'long', 'four', 'About', 'getting', 'give', '...', 'might', 'services', 'public', '|', 'Tuesday', 'shares', 'So', 'online', 'President', 'third', 'win', 'free', 'does', 'former', '"We', 'never', 'am', 'financial', '(through', 'available', '3', 'year.', 'American', 'Sept.', 'family', 'it.', 'become', 'price', 'continue', 'life', 'sales', 'provide', 'put', 'research', 'using', 'past', 'share', 'took', 'days', 'too', 'August', 'several', 'announced', 'When', 'members', 'according', 'without', 'able', 'within', 'games', 'That', 'must', 'why', 'One', 'current', 'call', 'quarter', 'experience', 'major', 'came', 'pay', 'among', 'away', 'early', 'story', 'From', 'left', 'global', 'real', '“I', 'final', 'County', 'National', '"The', 'Apple', 'Share', 'following', '(', 'p.m.', 'looking', 'money', 'view', 'coming', 'sure', 'based', 'country', 'run', 'news', 'companies', 'system', 'At', 'less', 'said:', 'After', 'growth', 'York', 'change', 'love', 'having', 'already', '4', 'went', 'leading', 'While', 'whether', 'said,', 'video', 'things', 'group', 'South', 'side', 'care', 'comes', 'held', 'large', 'power', 'service', 'Wednesday', '5', 'By', 'months', 'September,', 'management', 'playing', 'release', 'What', 'products', 'future', 'It’s', 'customers', 'News', 'started', '2015,', 'given', 'social', 'technology', 'hit', 'industry', 'return', 'rate', "don't", 'India', 'due', 'national', 'least', 'Center', 'food', 'include', 'car', '6', 'open', 'North', 'results', 'Inc.', 'taking', 'Facebook', 'San', 'expected', 'allow', 'record', 'chief', 'believe', 'close', 'today', 'average', 'Friday', 'version', 'small', 'six', 'meeting', 'Company', 'ever', 'near', 'These', '“We', 'Twitter', 'law', 'appeared', 'development', 'program', '7', 'decision', 'teams', '8', 'feel', 'deal', 'children', 'community', 'PR', 'together', 'further', 'time,', 'court', 'Department', 'bring', 'TV', 'man', "It's", 'lead', 'access', 'enough', 'University', 'provides', ...

# %% [markdown]
# most popular tokens

# %%
print(vocab[:50])
#print('...',len(vocab))
# Out:
# ['the', 'to', 'and', 'of', 'a', 'in', 'for', 'is', 'on', 'that', 'with', 'The', 'at', 'was', 'as', 'be', 'are', 'from', 'by', 'have', 'it', 'will', 'I', 'has', 'this', 'an', 'you', 'or', 'not', 'their', 'he', 'his', 'more', 'but', 'said', 'we', 'who', 'they', 'can', 'its', 'been', 'which', 'about', 'your', 'our', 'all', '-', 'were', 'also', 'out']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot([vocabcount[w] for w in vocab]);
plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_yscale("log", nonposy='clip')
plt.title('word distribution in headlines and discription')
plt.xlabel('rank')
plt.ylabel('total appearances');

# %% [markdown]
# always nice to see [Zipf's law](https://en.wikipedia.org/wiki/Zipf%27s_law)

# %% [markdown]
# # Index words

# %%
empty = 0 # RNN mask of no data
eos = 1  # end of sentence
start_idx = eos+1 # first real word

# %%
def get_idx(vocab, vocabcount):
    word2idx = dict((word, idx+start_idx) for idx,word in enumerate(vocab))
    word2idx['<empty>'] = empty
    word2idx['<eos>'] = eos
    
    #idx2word = dict((idx,word) for word,idx in word2idx.iteritems())
    idx2word = dict((idx,word) for word,idx in word2idx.items())
    dict.items

    return word2idx, idx2word

# %%
word2idx, idx2word = get_idx(vocab, vocabcount)

# %% [markdown]
# # Word Embedding

# %% [markdown]
# ## read GloVe

# %%
fname = 'glove.6B.%dd.txt'%embedding_dim
import os
'''
datadir_base = os.path.expanduser(os.path.join('~', '.keras'))
if not os.access(datadir_base, os.W_OK):
    datadir_base = os.path.join('/tmp', '.keras')
datadir = os.path.join(datadir_base, 'datasets')
'''
glove_name = os.path.join('data', fname)
'''
if not os.path.exists(glove_name):
    path = 'glove.6B.zip'
    path = get_file(path, origin="http://nlp.stanford.edu/data/glove.6B.zip")
    # !unzip {datadir}/{path}
'''
# Out:
# '\nif not os.path.exists(glove_name):\n    path = \'glove.6B.zip\'\n    path = get_file(path, origin="http://nlp.stanford.edu/data/glove.6B.zip")\n    !unzip {datadir}/{path}\n'

# %%
glove_n_symbols = !wc -l {glove_name}
glove_n_symbols = int(glove_n_symbols[0].split()[0])
glove_n_symbols
# Out:
# 400000

# %%
import numpy as np
glove_index_dict = {}
glove_embedding_weights = np.empty((glove_n_symbols, embedding_dim))
globale_scale=.1
with open(glove_name, 'r') as fp:
    i = 0
    for l in fp:
        l = l.strip().split()
        w = l[0]
        glove_index_dict[w] = i
        glove_embedding_weights[i,:] = list(map(float,l[1:]))
        #was previously without list https://stackoverflow.com/questions/37629828/typeerror-float-argument-must-be-a-string-or-a-number-not-list-python
        #glove_embedding_weights[i,:] = map(float,l[1:])
        #b = list(map(float, a[0].split("*")))
        i += 1
glove_embedding_weights *= globale_scale

# %%
glove_embedding_weights.std()
# Out:
# 0.040815727600190289

# %%
#for w,i in glove_index_dict.iteritems():
for w,i in glove_index_dict.items():
    w = w.lower()
    if w not in glove_index_dict:
        glove_index_dict[w] = i

# %% [markdown]
# ## embedding matrix

# %% [markdown]
# use GloVe to initialize embedding matrix

# %%
# generate random embedding with same scale as glove
np.random.seed(seed)
shape = (vocab_size, embedding_dim)
scale = glove_embedding_weights.std()*np.sqrt(12)/2 # uniform and not normal
embedding = np.random.uniform(low=-scale, high=scale, size=shape)
print('random-embedding/glove scale', scale, 'std', embedding.std())

# copy from glove weights of words that appear in our short vocabulary (idx2word)
c = 0
for i in range(vocab_size):
    w = idx2word[i]
    g = glove_index_dict.get(w, glove_index_dict.get(w.lower()))
    if g is None and w.startswith('#'): # glove has no hastags (I think...)
        w = w[1:]
        g = glove_index_dict.get(w, glove_index_dict.get(w.lower()))
    if g is not None:
        embedding[i,:] = glove_embedding_weights[g,:]
        c+=1
print('number of tokens, in small vocab, found in glove and copied to embedding', c,c/float(vocab_size))
# Out:
# random-embedding/glove scale 0.0706949139514 std 0.0408138249575
# number of tokens, in small vocab, found in glove and copied to embedding 22441 0.561025

# %% [markdown]
# lots of word in the full vocabulary (word2idx) are outside `vocab_size`.
# Build an alterantive which will map them to their closest match in glove but only if the match
# is good enough (cos distance above `glove_thr`)

# %%
glove_thr = 0.5

# %%
word2glove = {}
for w in word2idx:
    if w in glove_index_dict:
        g = w
    elif w.lower() in glove_index_dict:
        g = w.lower()
    elif w.startswith('#') and w[1:] in glove_index_dict:
        g = w[1:]
    elif w.startswith('#') and w[1:].lower() in glove_index_dict:
        g = w[1:].lower()
    else:
        continue
    word2glove[w] = g

# %% [markdown]
# for every word outside the embedding matrix find the closest word inside the mebedding matrix.
# Use cos distance of GloVe vectors.
#
# Allow for the last `nb_unknown_words` words inside the embedding matrix to be considered to be outside.
# Dont accept distances below `glove_thr`

# %%
normed_embedding = embedding/np.array([np.sqrt(np.dot(gweight,gweight)) for gweight in embedding])[:,None]

nb_unknown_words = 100

glove_match = []
#for w,idx in word2idx.iteritems():
for w,idx in word2idx.items():
    if idx >= vocab_size-nb_unknown_words and w.isalpha() and w in word2glove:
        gidx = glove_index_dict[word2glove[w]]
        gweight = glove_embedding_weights[gidx,:].copy()
        # find row in embedding that has the highest cos score with gweight
        gweight /= np.sqrt(np.dot(gweight,gweight))
        score = np.dot(normed_embedding[:vocab_size-nb_unknown_words], gweight)
        while True:
            embedding_idx = score.argmax()
            s = score[embedding_idx]
            if s < glove_thr:
                break
            if idx2word[embedding_idx] in word2glove :
                glove_match.append((w, embedding_idx, s)) 
                break
            score[embedding_idx] = -1
glove_match.sort(key = lambda x: -x[2])
print('# of glove substitutes found', len(glove_match))
# Out:
# # of glove substitutes found 6584

# %% [markdown]
# manually check that the worst substitutions we are going to do are good enough

# %%
for orig, sub, score in glove_match[-10:]:
    print(score, orig,'=>', idx2word[sub])
# Out:
# 0.500827183647 Joss => creator
# 0.500697991011 participative => broad-based
# 0.500680991567 reticle => crosshair
# 0.500659397468 Cowart => Shumpert
# 0.500554290739 Picard => Noe
# 0.500435582577 Fontana => gallo
# 0.500322085518 Muppet => Emmerdale
# 0.500273590268 Deadpool => Team-up
# 0.500258961216 Tris => Zych
# 0.500242131117 Torrisi => Savea

# %% [markdown]
# build a lookup table of index of outside words to index of inside words

# %%
glove_idx2idx = dict((word2idx[w],embedding_idx) for  w, embedding_idx, _ in glove_match)

# %% [markdown]
# # Data

# %%
Y = [[word2idx[token] for token in headline.split()] for headline in heads]
len(Y)
# Out:
# 999

# %%
plt.hist(list(map(len,Y)),bins=50);

# %%
X = [[word2idx[token] for token in d.split()] for d in desc]
len(X)
# Out:
# 999

# %%
plt.hist(list(map(len,X)),bins=50);

# %%
#import cPickle as pickle
with open('data/%s.pkl'%FN,'wb') as fp:
    pickle.dump((embedding, idx2word, word2idx, glove_idx2idx),fp,-1)

# %%
#import cPickle as pickle
with open('data/%s.data.pkl'%FN,'wb') as fp:
    pickle.dump((X,Y),fp,-1)
